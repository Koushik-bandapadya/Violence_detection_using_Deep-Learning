# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
from tqdm import tqdm

# %% [markdown]
# Extracting(Hocky)

# %%
output_path='/DataSet/Extract_frames(Hocky)/'
IMG_SIZE = 100

def extract_frames(folder):
    c = 0
    for folders in os.listdir(folder):
        print(folders)
        folder_path = os.path.join(folder, folders)
        for files in tqdm(os.listdir(folder_path)):
            path = os.path.join(folder_path, files)
            cap = cv2.VideoCapture(path)
            success = True

            while success:
                success, image = cap.read()
                if not success:
                    break
                
                cv2.resize(cv2.imwrite(output_path+ str(c) + '.jpg', image), (IMG_SIZE, IMG_SIZE))
                c += 1
        print(c)
        print('Done: ' + folders)

# %% [markdown]
# HockyFrame_Extraction

# %%
extract_frames('/DataSet/Hockey Fights')
# Out:
# Non Violent
# 100%|██████████| 500/500 [03:18<00:00,  2.53it/s]
# 20499
# Done: Non Violent
# Violent
# 100%|██████████| 500/500 [03:11<00:00,  2.61it/s]
# 41056
# Done: Violent

# %% [markdown]
# Optim

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'

# %% [markdown]
# Extracting(Movie)

# %%
output_path='/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Movie)/movie'
IMG_SIZE = 100

def extract_frames(folder):
    c = 0
    for folders in os.listdir(folder):
        print(folders)
        folder_path = os.path.join(folder, folders)
        for files in tqdm(os.listdir(folder_path)):
            path = os.path.join(folder_path, files)
            cap = cv2.VideoCapture(path)
            success = True

            while success:
                success, image = cap.read()
                if not success:
                    break
                
                cv2.resize(cv2.imwrite(output_path+ str(c) + '.jpg', image), (IMG_SIZE, IMG_SIZE))
                c += 1
        print(c)
        print('Done: ' + folders)

# %% [markdown]
# **MovieFrame_Extraction**

# %%
extract_frames('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Movie DataSet')
# Out:
# Violent
# 100%|██████████| 100/100 [03:15<00:00,  1.96s/it]
# 4791
# Done: Violent
# Non Violent
# 100%|██████████| 101/101 [02:46<00:00,  1.65s/it]
# 9740
# Done: Non Violent

# %% [markdown]
# Optim

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'

# %% [markdown]
# Extracting(Violent Flows Dataset)

# %%
output_path='/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Violent Flows Dataset)/VFData'
IMG_SIZE = 100

def extract_frames(folder):
    c = 0
    for folders in os.listdir(folder):
        print(folders)
        folder_path = os.path.join(folder, folders)
        for files in tqdm(os.listdir(folder_path)):
            path = os.path.join(folder_path, files)
            cap = cv2.VideoCapture(path)
            success = True

            while success:
                success, image = cap.read()
                if not success:
                    break
                
                cv2.resize(cv2.imwrite(output_path+ str(c) + '.jpg', image), (IMG_SIZE, IMG_SIZE))
                c += 1
        print(c)
        print('Done: ' + folders)

# %% [markdown]
# Violent Flows Dataset Frame_Extraction

# %%
extract_frames('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Violent Flows Dataset')
# Out:
# Non Violent
# 100%|██████████| 123/123 [01:46<00:00,  1.15it/s]
# 9544
# Done: Non Violent
# Violent
# 100%|██████████| 110/110 [03:07<00:00,  1.70s/it]
# 28957
# Done: Violent

# %% [markdown]
# Optim

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'

# %% [markdown]
# Optim Frame

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'
NUM_FRAMES=10

# %%
IMG_SIZE = 100
NUM_FRAMES= 10

# %% [markdown]
# CreateDataset movie

# %%
def create_dataset():
    IMG_SIZE = 100
    dataset = []
    image = []
    limit = 0
    c = 0

    for file in tqdm(os.listdir('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Movie)')):
        path = os.path.join('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Movie)', file)
        try:
          img = cv2.resize(cv2.imread(path), (IMG_SIZE, IMG_SIZE))
          image.append(np.array(img))
          limit += 1
          c += 1
          if c == NUM_FRAMES:
              c = 0
              if limit < 4792 :
                  dataset.append([image, np.array([1, 0])])
              elif limit >= 4792 :
                  dataset.append([image, np.array([0, 1])])
              image = []
        except:
          continue
    
    shuffle(dataset)
    np.save('/content/drive/MyDrive/CSE299(CNN BiLSTM)/numpy/dataset_movie.npy', dataset)
    return dataset

# %% [markdown]
# Create

# %%
data = create_dataset()
# Out:
# 100%|██████████| 9742/9742 [01:38<00:00, 99.33it/s]
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Optim Frame

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'
NUM_FRAMES=10

# %%
IMG_SIZE = 100
NUM_FRAMES= 10

# %% [markdown]
# CreateDataset violanceFLow

# %%
def create_dataset():
    IMG_SIZE = 100
    dataset = []
    image = []
    limit = 0
    c = 0

    for file in tqdm(os.listdir('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Violent Flows Dataset)')):
        path = os.path.join('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Violent Flows Dataset)', file)
        try:
          img = cv2.resize(cv2.imread(path), (IMG_SIZE, IMG_SIZE))
          image.append(np.array(img))
          limit += 1
          c += 1
          if c == NUM_FRAMES:
              c = 0
              if limit < 9545 :
                  dataset.append([image, np.array([1, 0])])
              elif limit >= 9545 :
                  dataset.append([image, np.array([0, 1])])
              image = []
        except:
          continue
    
    shuffle(dataset)
    np.save('/content/drive/MyDrive/CSE299(CNN BiLSTM)/numpy/dataset_VF.npy', dataset)
    return dataset

# %%
data = create_dataset()
# Out:
# 100%|██████████| 28959/28959 [02:32<00:00, 189.48it/s]
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Optim Frame

# %%
OPTIM='SGD'
LR=0.01
decay=1e-6
EPOCHS=25
BATCH_SIZE=5
LOSS='sparse categorical crossentropy'
NUM_FRAMES=10

# %%
IMG_SIZE = 100
NUM_FRAMES= 10

# %% [markdown]
# CreateDataset HockyFrame

# %%
def create_dataset():
    IMG_SIZE = 100
    dataset = []
    image = []
    limit = 0
    c = 0

    for file in tqdm(os.listdir('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Hocky)')):
        path = os.path.join('/content/drive/MyDrive/CSE299(CNN BiLSTM)/DataSet/Extract_frames(Hocky)', file)
        try:
          img = cv2.resize(cv2.imread(path), (IMG_SIZE, IMG_SIZE))
          image.append(np.array(img))
          limit += 1
          c += 1
          if c == NUM_FRAMES:
              c = 0
              if limit < 20556 :
                  dataset.append([image, np.array([1, 0])])
              elif limit >= 20556 :
                  dataset.append([image, np.array([0, 1])])
              image = []
        except:
          continue
    
    shuffle(dataset)
    np.save('/content/drive/MyDrive/CSE299(CNN BiLSTM)/numpy/dataset_hocky1.npy', dataset)
    return dataset

# %%
data = create_dataset()

# %%
train = data[:-400]
test = data[-400:]

# %% [markdown]
# Creating the Model

# %%
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, TimeDistributed,Dropout, Activation, Flatten,Conv2D, MaxPooling2D,LSTM,Bidirectional, Reshape
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import Input

inputs = Input(shape=[10, IMG_SIZE, IMG_SIZE, 3], name= "input")
convrnn = Conv2D(64, (3, 3), activation='relu', padding = 'same')(inputs)
convrnn = Conv2D(64, (3, 3), activation='relu')(convrnn)
print(convrnn[0][0].shape)
convrnn = MaxPooling2D((2,2))(convrnn[0])
print(convrnn.shape)
convrnn = Conv2D(64, (3, 3), activation='relu')(convrnn)
print(convrnn.shape)
convrnn = MaxPooling2D((2,2))(convrnn)
print(convrnn.shape)
convrnn = Conv2D(64, (3, 3), activation='relu')(convrnn)
convrnn = MaxPooling2D((2,2))(convrnn)
print(convrnn.shape)
convrnn = Flatten()(convrnn)
print(convrnn.shape)

convrnn = tf.reshape(convrnn, (1, 10, 6400))
# print(convrnn.shape)

lstm_fw = LSTM(units=32)
lstm_bw = LSTM(units=32, go_backwards=True)
bi_lstm = Bidirectional(lstm_fw, backward_layer=lstm_bw)(convrnn)

convrnn = Dense(64, activation= 'relu')(bi_lstm)
convrnn = Dense(32, activation= 'relu')(convrnn)
output = Dense(1, activation='sigmoid')(convrnn)

model = tf.keras.Model(inputs = inputs, outputs = output)
model.summary()

# %%
len(train[0][1])
# Out:
# 2

# %%
import tensorflow
from tensorflow.keras.layers import LSTM, Bidirectional, Conv2D, Dense, Flatten, MaxPooling2D, TimeDistributed, Reshape, MaxPooling3D
from tensorflow.keras.models import Sequential
from tensorflow import keras
from tensorflow.keras.optimizers import Adam, SGD

cnn = Sequential()
cnn.add(Conv2D(64, (3, 3), activation='relu', input_shape=(10, IMG_SIZE, IMG_SIZE, 3), padding="same"))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling3D((1, 2,2)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling3D((1, 2,2)))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling3D((1, 2,2)))
#cnn.add(Flatten())
cnn.add(Reshape((10, 6400)))

#cnn.summary()

lstm_fw = LSTM(units=32)
lstm_bw = LSTM(units=32, go_backwards = True)
model = Sequential()
#model.add(TimeDistributed(cnn, input_shape=(1, 10, 10, 64)))
model.add(Bidirectional(lstm_fw, backward_layer = lstm_bw))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

cnn.add(Bidirectional(lstm_fw, backward_layer = lstm_bw))
cnn.add(Dense(64, activation='relu'))
cnn.add(Dense(32, activation='relu'))
cnn.add(Dense(2, activation='sigmoid'))

cnn.summary()
LR = 0.0001
opt = tensorflow.keras.optimizers.Adam(learning_rate=LR)
cnn.compile(loss='categorical_crossentropy',optimizer='SGD',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 10, 100, 100, 64)  1792
#
#  conv2d_1 (Conv2D)           (None, 10, 98, 98, 64)    36928
#
#  max_pooling3d (MaxPooling3D  (None, 10, 49, 49, 64)   0
#  )
#
#  conv2d_2 (Conv2D)           (None, 10, 47, 47, 64)    36928
#
#  max_pooling3d_1 (MaxPooling  (None, 10, 23, 23, 64)   0
#  3D)
#
#  conv2d_3 (Conv2D)           (None, 10, 21, 21, 64)    36928
#
#  max_pooling3d_2 (MaxPooling  (None, 10, 10, 10, 64)   0
#  3D)
#
#  reshape (Reshape)           (None, 10, 6400)          0
#
#  bidirectional_1 (Bidirectio  (None, 64)               1646848
#  nal)
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 2)                 66
#
# ...
# Total params: 1,765,730
# Trainable params: 1,765,730
# ...

# %% [markdown]
# load hockyFight dataset numpy array

# %%
data = np.load('/numpy/dataset_hocky.npy', allow_pickle=True)

# %%
train, test = train_test_split(data, train_size= 0.9, shuffle=True)

# %%
train[0][1]
# Out:
# array([0, 1])

# %%
X = np.array([i[0] for i in train]).reshape(-1, 10, IMG_SIZE, IMG_SIZE, 3)
Y = np.array([i[1] for i in train])

x_valid = np.array([i[0] for i in test]).reshape(-1, 10, IMG_SIZE, IMG_SIZE, 3)
y_valid = np.array([i[1] for i in test])

# %%
X = X.astype('float32')/255
x_valid = x_valid.astype('float32')/255

# %%
x_try = X[:20]
y_try = Y[:20]
print(len(x_try), len(y_try))
# Out:
# 20 20

# %%
cnn.fit(X,Y,epochs=10,validation_data=(x_valid,y_valid),batch_size=16, verbose=1)
# Out:
# Epoch 1/10
#   2/231 [..............................] - ETA: 1:57:47 - loss: 0.6925 - accuracy: 0.5000

# %%
cnn.save('/content/drive/MyDrive/CSE299(CNN BiLSTM)/Model(h5 file)/CNN-BiLSTM.h5', overwrite=True, include_optimizer=True)
