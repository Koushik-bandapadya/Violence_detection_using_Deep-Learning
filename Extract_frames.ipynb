# %% [markdown]
# Modules Import

# %%
import cv2
import os

# %% [markdown]
# video

# %%
count=0
cap= cv2.VideoCapture('https://drive.google.com/file/d/1BXvMUTjFzaNK-d1Y8P3sM50wBm6pO_hF/view?usp=sharing')
success,image=cap.read()

print(success)
# Out:
# False
